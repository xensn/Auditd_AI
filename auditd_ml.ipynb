# %% [markdown]
# # Auditd Machine Learning

# %% [markdown]
# Focused Attack Types: Reconnaissance, Privilege Escalation, Persistence, and Data Exfiltration

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import csv

# %%
with open('test.txt', "r") as file:
    for line_num, line in enumerate(file):

        if "----" in line:
            continue # Skip the lines with ---- in it
        
        line_array = line.strip().split(' ') # Split the lines into array for cleaning

        #if line_array[1] == "----":
            #continue # Skip the lines with ---- in it

        if ":" in line_array:
            line_array.remove(":") # Remove the : in each line of log

        if "\"" in line_array:
            line_array.remove("\"") # Remove the " in each line of log
        
        for i in line_array:
            # Remove " from the msg field
            if '"' in i:
                index = line_array.index(i)
                line_array[index] = line_array[index].replace('"', "")
            
            # Combine msg field into one entry
            if "msg=" in i:
                index = line_array.index(i)
                line_array[index] = line_array[index] + " " + line_array[index + 1]
                line_array.pop(index + 1)
            
            # Skip ausearch commands being ran
            time = ""
            if "ausearch" in i:
                    time = line_array[4]
                    print(i)

        print(line_array)

        with open("training_data.csv", "a", newline='') as csv_file:
            if time == line_array[4]:
                continue
            else:
                write = csv.writer(csv_file)
                write.writerow(line_array)
# Out:
# comm=ausearch
# exe=/usr/sbin/ausearch
# ['BENIGN', 'type=SYSCALL', 'msg=audit(09/19/2025 18:17:32.558:12757524)', 'arch=x86_64', 'syscall=execve', 'success=yes', 'exit=0', 'a0=0x5afa09a98a98', 'a1=0x5afa09a05d90', 'a2=0x5afa09a99750', 'a3=0x64', 'items=2', 'ppid=99813', 'pid=99814', 'auid=ubuntu', 'uid=root', 'gid=root', 'euid=root', 'suid=root', 'fsuid=root', 'egid=root', 'sgid=root', 'fsgid=root', 'tty=pts6', 'ses=240', 'comm=ausearch', 'exe=/usr/sbin/ausearch', 'subj=unconfined', 'key=audittools']
# ausearch
# ['BENIGN', 'type=PROCTITLE', 'msg=audit(09/19/2025 18:17:32.530:12757509)', 'proctitle=sudo', 'ausearch', '-ts', '09/19/2025', '18:17:09', '-te', '09/19/2025', '18:17:32', '-i']
# ['BENIGN', 'type=PATH', 'msg=audit(09/19/2025 18:17:32.530:12757509)', 'item=0', 'name=/var/run/nscd/socket', 'nametype=UNKNOWN', 'cap_fp=none', 'cap_fi=none', 'cap_fe=0', 'cap_fver=0', 'cap_frootid=0']
# ['BENIGN', 'type=SOCKADDR', 'msg=audit(09/19/2025 18:17:32.530:12757509)', 'saddr={', 'saddr_fam=local', 'path=/var/run/nscd/socket', '}']
# ['BENIGN', 'type=SYSCALL', 'msg=audit(09/19/2025 18:17:32.530:12757509)', 'arch=x86_64', 'syscall=connect', 'success=no', 'exit=ENOENT(No', 'such', 'file', 'or', 'directory)', 'a0=0x6', 'a1=0x7ffd45f71d60', 'a2=0x6e', 'a3=0x14', 'items=1', 'ppid=64365', 'pid=99812', 'auid=ubuntu', 'uid=root', 'gid=root', 'euid=root', 'suid=root', 'fsuid=root', 'egid=root', 'sgid=root', 'fsgid=root', 'tty=pts5', 'ses=240', 'comm=sudo', 'exe=/usr/bin/sudo', 'subj=unconfined', 'key=network']
